# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR="D:/Dataset/NF/test"
CATEGORIES=["cats","dogs"]

# %%
for category in CATEGORIES:
    path= os.path.join(DATADIR,category)
    for img in os.listdir(path):
        img_array= cv2.imread(os.path.join(path,img))
        #print(str(img_array))
        plt.imshow(img_array)
        plt.show()
        break
    break

# %%
print(img_array.shape)
# Out:
# (415, 498, 3)

# %%
IMG_SIZE=224
i=1
img_array= cv2.imread(os.path.join("D:/Dataset/NF/test/Img","cat_0001.jpg"),cv2.IMREAD_GRAYSCALE)
new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
cv2.imwrite("D:/Dataset/NF/cat" + "_%04i.jpg"%i, new_array)
plt.imshow(new_array,cmap="gray")
print(new_array.shape)
# Out:
# (224, 224)

# %%
DATADIR="D:/Dataset/NF/test"
CATEGORIES=["cats","dogs"]

resize_image=[]
def create_resize_image():
    i=1
    for category in CATEGORIES:
        path= os.path.join(DATADIR,category) # 0 for normal and 1 for PNEUMONIA
        #path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
                img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                if i<=1000: # 1000 is total number of images in Cat folder
                    cv2.imwrite("D:/Dataset/NF/test/ImgCat/cat" + "_%04i.jpg"%i, new_array)
                else:
                    cv2.imwrite("D:/Dataset/NF/test/ImgDog/dog" + "_%04i.jpg"%i, new_array)
                #plt.imshow(new_array,cmap="gray")
                print(new_array.shape)
                i+=1
                
create_resize_image()
# Out:
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# (224, 224)
# ...

# %%
DATADIR="D:/Dataset/NF/training"
CATEGORIES=["cats","dogs"]

resize_image=[]
def create_resize_image():
    i=1
    for category in CATEGORIES:
        path= os.path.join(DATADIR,category) # 0 for normal and 1 for PNEUMONIA
        #path= os.path.join(DATADIR) # 0 for normal and 1 for PNEUMONIA
        class_num=CATEGORIES.index(category)
        for img in os.listdir(path):
                img_array= cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                if i<=4000: # 4000 is total number of images in Cat folder
                    cv2.imwrite("D:/Dataset/NF/training/ImgCat/cat" + "_%04i.jpg"%i, new_array)
                else:
                    cv2.imwrite("D:/Dataset/NF/training/ImgDog/dog" + "_%04i.jpg"%i, new_array)
                #plt.imshow(new_array,cmap="gray")
                #print(new_array.shape)
                i+=1
                
create_resize_image()
